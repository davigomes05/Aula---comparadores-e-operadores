# %% [markdown]
# <a href="https://colab.research.google.com/github/davigomes05/Aula---comparadores-e-operadores/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("8 é maior quen 6:", 8 > 6)
print("8 é menor que 7:" 8 < 7)
print(8==7)
print(10>=10)
print(10<10)
print(10<=10)

# %%
idade = int(input("Digite sua idade: "))
idade2 = int(input("Digite sua idade: "))
print(idade ==idade2)
print(idade != idade2)
print(idade > idade2)
print(idade >= idade2)
print(idade < idade2)
print(idade <= idade2)

# %% [markdown]
#       AND
#   F   F   V
#   V   V   V
#   F   V   F
#   V   F   F

# %%
idade = int(input("Digite sua idade: "))
convite = input("Tem convite? (sim/nao)")
resultado = (idade >= 18) and (convite == "sim")
print(resultado)

# %%
##### Atividade 02
usuario = input("Digite seu usuário: ")
senha = input("Digite sua senha: ")
resultado = (usuario == "admin") and (senha == "1234")
print(resultado)

# %%
vip = input("Você é cliente vip? sim/nao:")
valor = float(input("Digite o valor da compra: "))
resultado = (vip == "sim") and (valor > 100)
print(resultado)

# %%
dia = input("Digite o dia da semana: ")
resultado = (dia == "segunda" or dia == "terca" or dia == "quarta" or dia == "quinta" or dia == "sexta")
print(resultado)
